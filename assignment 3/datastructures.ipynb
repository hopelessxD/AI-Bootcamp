# %% [markdown]
# #list

# %%
numbers = [1,2,3,4,'apple',5]
print(numbers)
numbers[-3]
# Out:
# [1, 2, 3, 4, 'apple', 5]
# 4

# %%
numbers.append(6)
print(numbers)
# Out:
# [1, 2, 3, 4, 'apple', 5, 6, 6, 6, 6]

# %%
numbers.remove(3)
print(numbers)
# Out:
# [1, 2, 4, 'apple', 5]

# %%
unsorted = [1,6,7,2,4]
unsorted.sort()
print(unsorted)
# Out:
# [1, 2, 4, 6, 7]

# %% [markdown]
# #list comprehension

# %%
square = [num **  3 for num in range (0,10)]
print(square)
# Out:
# [0, 1, 16, 81, 256, 625, 1296, 2401, 4096, 6561]

# %% [markdown]
# ## equivalence of the above code

# %%
sq= []
for num in range(0,5):
  sq.append(num**2)

print(sq)
# Out:
# [0, 1, 4, 9, 16]

# %% [markdown]
# #Dictionary

# %%
colors= {"apple": "red", 2:5, 3:'green'}
print(colors)
# Out:
# {'apple': 'red', 2: 5, 3: 'green'}

# %%
colors[3]
# Out:
# 'green'

# %%
dic = {1:'one', 2:'two', list:sq}
dic[4]= 'four'
print(dic)
# Out:
# {1: 'one', 2: 'two', <class 'list'>: [0, 1, 4, 9, 16], 4: 'four'}

# %% [markdown]
# #Tuple

# %%
tutu= (1,2,3,4)
tutu
# Out:
# (1, 2, 3, 4)

# %% [markdown]
# #Set

# %% [markdown]
# no recurring values

# %%
sett= (1,2,3,4,5,5,5,6,7,6,6)
setno= set(sett)
setno
# Out:
# {1, 2, 3, 4, 5, 6, 7}
